# %%
import pandas as pd
import numpy as np
import random

# %%
# sample from a normal distribution using numpy's random number generator

sample = np.random.normal(loc=0.0, scale=1.0, size=100000)
sample
# Out:
# array([-0.98127985,  0.88902297, -0.76996626, ...,  0.45271313,
#         1.00036764, -0.13019712])

# %%
# plot the normal distribution

import matplotlib.pyplot as plt

normal = plt.hist(sample, bins=50)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-5, 5, 0.01)
  
# Calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
  
plt.plot(x_axis, norm.pdf(x_axis, 0, 1))
plt.show()

# %%
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-5, 5, 0.01)
  
# Calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)

normals = [[0,1], 
           [4, 2]]
final = 0
for normal in normals:
    dist = norm.pdf(x_axis, normal[0], normal[1])
    final = final + dist

  
plt.plot(x_axis, final)
plt.show()
